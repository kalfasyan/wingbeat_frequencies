# %%
# %reset -f
# import the necessary packages
from sklearn.metrics import classification_report
from keras.datasets import cifar10
import autokeras as ak
import os

# initialize the output directory
OUTPUT_PATH = "output"
# initialize the list of training times that we'll allow
# Auto-Keras to train for
TRAINING_TIMES = [
    60 * 60,        # 1 hour
    60 * 60 * 2,    # 2 hours
    60 * 60 * 4,    # 4 hours
    60 * 60 * 8,    # 8 hours
    60 * 60 * 12,   # 12 hours
    60 * 60 * 24,   # 24 hours
]
# Out:
# Using TensorFlow backend.

# %%
# load the training and testing data, then scale it into the
# range [0, 1]
print("[INFO] loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float") / 255.0
testX = testX.astype("float") / 255.0
# Out:
# [INFO] loading CIFAR-10 data...

# %%
# initialize the label names for the CIFAR-10 dataset
labelNames = ["airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"]
# loop over the number of seconds to allow the current Auto-Keras
# model to train for
for seconds in TRAINING_TIMES:
    # train our Auto-Keras model
    print("[INFO] training model for {} seconds max...".format(
        seconds))
    model = ak.ImageClassifier(verbose=True)
    print('s')
    model.fit(trainX, trainY, time_limit=seconds)
    model.final_fit(trainX, trainY, testX, testY, retrain=True)

    # evaluate the Auto-Keras model
    score = model.evaluate(testX, testY)
    predictions = model.predict(testX)
    report = classification_report(testY, predictions,
        target_names=labelNames)

    # write the report to disk
    p = os.path.sep.join(OUTPUT_PATH, "{}.txt".format(seconds))
    f = open(p, "w")
    f.write(report)
    f.write("\nscore: {}".format(score))
    f.close()
# Out:
# [INFO] training model for 3600 seconds max...
# Saving Directory: /tmp/autokeras_PN9XSO
# s
# Preprocessing the images.
# Preprocessing finished.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 0               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 1               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 2               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 3               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 4               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 5               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 6               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 7               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 8               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 9               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 10               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 11               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 12               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 13               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 14               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 15               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 16               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 17               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 18               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 19               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 20               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 21               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 22               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 23               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 24               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 25               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 26               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 27               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 28               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 29               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 30               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 31               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 32               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 33               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 34               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 35               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 36               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 37               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 38               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 39               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 40               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 41               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 42               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 43               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 44               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 45               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 46               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 47               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 48               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 49               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 50               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 51               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 52               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 53               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 54               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 55               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 56               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 57               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 58               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 59               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 60               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 61               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 62               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 63               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 64               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 65               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 66               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 67               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 68               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 69               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 70               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 71               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 72               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 73               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 74               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 75               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 76               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 77               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 78               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 79               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 80               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 81               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 82               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 83               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 84               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 85               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 86               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 87               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 88               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 89               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 90               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 91               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 92               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 93               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 94               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 95               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 96               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 97               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 98               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 99               |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 100              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 101              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 102              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 103              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 104              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 105              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 106              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 107              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 108              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 109              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 110              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 111              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 112              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 113              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 114              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 115              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 116              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 117              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 118              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 119              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 120              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 121              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 122              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 123              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 124              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 125              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 126              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 127              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 128              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 129              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 130              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 131              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 132              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 133              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 134              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 135              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 136              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 137              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 138              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 139              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 140              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 141              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 142              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 143              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 144              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 145              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 146              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 147              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 148              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 149              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 150              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 151              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 152              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 153              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 154              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 155              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 156              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 157              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 158              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 159              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 160              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 161              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 162              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 163              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 164              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# ...
#
#
# +----------------------------------------------+
# |              Training model 227              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 228              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 229              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 230              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 231              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 232              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 233              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 234              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 235              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 236              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 237              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 238              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 239              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 240              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 241              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 242              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 243              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 244              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 245              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 246              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 247              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 248              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 249              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 250              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 251              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 252              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 253              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 254              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 255              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 256              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 257              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 258              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 259              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 260              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 261              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 262              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 263              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 264              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 265              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 266              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 267              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 268              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 269              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 270              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 271              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 272              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 273              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 274              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |              Training model 275              |
# +----------------------------------------------+
#
# Current model size is too big. Discontinuing training this model to search for other models.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c68a59bc19ed> in <module>()
#      10     model = ak.ImageClassifier(verbose=True)
#      11     print('s')
# ---> 12     model.fit(trainX, trainY, time_limit=seconds)
#      13     model.final_fit(trainX, trainY, testX, testY, retrain=True)
#      14
#
# /home/kalfasyan/.local/lib/python3.6/site-packages/autokeras/image/image_supervised.py in fit(self, x, y, time_limit)
#     128             print("Preprocessing finished.")
#     129
# --> 130         super().fit(x, y, time_limit)
#     131
#     132     def init_transformer(self, x):
#
# /home/kalfasyan/.local/lib/python3.6/site-packages/autokeras/supervised.py in fit(self, x, y, time_limit)
#     138             time_limit = 24 * 60 * 60
#     139
# --> 140         self.cnn.fit(self.get_n_output_node(), x_train.shape, train_data, test_data, time_limit)
#     141
#     142     def final_fit(self, x_train, y_train, x_test, y_test, trainer_args=None, retrain=False):
#
# /home/kalfasyan/.local/lib/python3.6/site-packages/autokeras/net_module.py in fit(self, n_output_node, input_shape, train_data, test_data, time_limit)
#      71             while time_remain > 0:
#      72                 self.searcher.search(train_data, test_data, int(time_remain))
# ---> 73                 pickle_to_file(self, os.path.join(self.path, 'module'))
#      74                 if len(self.searcher.history) >= Constant.MAX_MODEL_NUM:
#      75                     break
#
# /home/kalfasyan/.local/lib/python3.6/site-packages/autokeras/utils.py in pickle_to_file(obj, path)
#      51 def pickle_to_file(obj, path):
#      52     """Save the pickle file to the specified path."""
# ---> 53     pickle.dump(obj, open(path, 'wb'))
#      54
#      55
#
# KeyboardInterrupt:

# %%
# Out:
# [INFO] loading CIFAR-10 data...
