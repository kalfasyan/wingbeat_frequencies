# %%
import pandas as pd
from wavhandler import *

# %%
df = pd.read_csv('mosquitos.csv', delimiter=';')

# %%
df.shape
# Out:
# (279566, 21)

# %%
df.sample(10)
# Out:
#         Unnamed: 0  Unnamed: 0.1                                   fname  \
# 22949        22949         22949                F170208_155837_187_G_050
# 86643        86643         86643                F170103_011608_131_G_050
# 145938       40154         40154                F170119_170346_220_G_050
# 180115        5563          5563  F170213_210644_173_G_050_T_25.9_H_64.3
# 13647        13647         13647                F170207_174820_114_G_050
# 241320       66768         66768                F161220_010842_001_G_050
# 198515       23963         23963  F170217_134355_151_G_050_T_25.9_H_71.1
# 136856       31072         31072                F170117_231920_098_G_050
# 236303       61751         61751                F161219_231510_104_G_050
# 160353       54569         54569                F170121_144337_043_G_050
#
#                                                     names      class  \
# 22949   /home/yannis/data/insects/Potamitis/Wingbeats/...      Aedes
# ...
