# %%
import pandas as pd
import numpy as np
import os
from utils import *
from wavhandler import *

# %%
DATADIR = '/home/kalfasyan/data/insects/increasing dataset/'
target_names = os.listdir(DATADIR)

# %%
print(target_names)

# %%
from os import walk
 
def list_files2(directory, extension):
    for (dirpath, dirnames, filenames) in walk(directory):
        return (f for f in filenames if f.endswith('.' + extension))
    
mydir = DATADIR+target_names[0]
mydir_generator = list_files2(mydir, 'mat')
for i in mydir_generator:
    file = os.path.join(mydir,i)

# %%
from scipy.io import loadmat

mat = loadmat(file)['labels']

# %%
X,y,_ = get_data(filedir='/home/kalfasyan/data/insects/increasing dataset/', target_names=target_names[:2], nr_signals=np.inf, only_names=False)
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.63it/s]

# %%
import matplotlib.pyplot as plt
rdm = np.random.randint(0, X.shape[0])
plt.plot(X[rdm, :])

# %%
X_transformed = transform_data(X)
# Out:
# 100%|██████████| 10000/10000 [00:13<00:00, 755.86it/s]

# %%
rdm = np.random.randint(0, X_transformed.shape[0])
plt.plot(X_transformed[rdm, :])

# %%
# scipy to load matalab .mat file
# ____________________

#os.listdir(DATADIR+target_names[0])
DATADIR+target_names[0]
# Out:
# '/home/kalfasyan/data/insects/increasing dataset/stigma_female'
