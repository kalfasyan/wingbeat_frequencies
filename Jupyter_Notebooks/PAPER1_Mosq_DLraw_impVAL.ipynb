# %%
# %reset -f
import sys
sys.path.insert(0,'..')
from wavhandler import *
# from utils_train import train_test_val_split
from pandas.plotting import register_matplotlib_converters
from utils_train import test_inds, test_days
register_matplotlib_converters()

# %%
data = Dataset('Wingbeats')
print(data.target_classes)

def train_test_filenames(dataset, species, train_dates=[], test_dates=[]):
    dataset.read(species, loadmat=False)
    dataset.get_sensor_features()
    sub = dataset.df_features
    sub.groupby('datestr')['filenames'].count().plot(kind="bar")
    print(sub['datestr'].unique().tolist())

    test_fnames = sub[sub.datestr.isin(test_dates)].filenames
    if len(train_dates): # if train dates are given
        train_fnames = sub[sub.datestr.isin(train_dates)].filenames
    else:
        train_fnames = sub[~sub.datestr.isin(test_dates)].filenames

    print("{} train filenames, {} test filenames".format(train_fnames.shape[0], test_fnames.shape[0]))
    return train_fnames, test_fnames
# Out:
# ['Ae. aegypti', 'Ae. albopictus', 'An. arabiensis', 'An. gambiae', 'C. pipiens', 'C. quinquefasciatus']

# %% [markdown]
# ### Ae. Aegypti

# %%
x1_tr, x1_ts = train_test_filenames(data,'Ae. aegypti', test_dates=['20161213','20161212'])
# Out:
# Data: Ae. aegypti.
# Read 85553 filenames in 2.36 seconds.
# ['20170209', '20170208', '20170210', '20170206', '20170213', '20170211', '20170207', '20161213', '20170212', '20161212']
# 82989 train filenames, 2564 test filenames

# %% [markdown]
# ### Ae. albopictus

# %%
x2_tr, x2_ts = train_test_filenames(data,'Ae. albopictus', test_dates=['20170103', '20170102'])
# Out:
# Data: Ae. albopictus.
# Read 20231 filenames in 2.34 seconds.
# ['20170301', '20170228', '20170227', '20170103', '20170102']
# 17440 train filenames, 2791 test filenames

# %% [markdown]
# ### An. arabiensis

# %%
x3_tr, x3_ts = train_test_filenames(data,'An. arabiensis', test_dates=['20170319','20170320',
                                                                       '20170318','20170317'], train_dates=['20170201','20170202', '20170203','20170204',
                                                                                                            '20170205','20170206','20170131','20170130'])
# Out:
# Data: An. arabiensis.
# Read 19297 filenames in 2.36 seconds.
# ['20170313', '20170202', '20170315', '20170314', '20170318', '20170204', '20170201', '20170131', '20170203', '20170317', '20170320', '20170319', '20170316', '20170205', '20170206', '20170130']
# 12897 train filenames, 2831 test filenames

# %% [markdown]
# ### An. gambiae

# %%
x4_tr, x4_ts = train_test_filenames(data,'An. gambiae', test_dates=['20170110', '20170109'])
# Out:
# Data: An. gambiae.
# Read 49471 filenames in 2.42 seconds.
# ['20170110', '20170109', '20170116', '20170119', '20170120', '20170117', '20170121', '20170118', '20170122', '20170123']
# 45471 train filenames, 4000 test filenames

# %% [markdown]
# ### Culex quinquefasciatus

# %%
x5_tr, x5_ts = train_test_filenames(data,'C. quinquefasciatus', test_dates=['20161219'])
# Out:
# Data: C. quinquefasciatus.
# Read 74599 filenames in 2.36 seconds.
# ['20161220', '20161219', '20161221']
# 41552 train filenames, 33047 test filenames

# %% [markdown]
# ### Culex pipiens

# %%
x6_tr, x6_ts = train_test_filenames(data,'C. pipiens', test_dates=['20161206', '20161205'])
# Out:
# Data: C. pipiens.
# Read 30415 filenames in 2.47 seconds.
# ['20161206', '20161205', '20170215', '20170216', '20170220', '20170217', '20170214', '20170213', '20170219', '20170218']
# 28353 train filenames, 2062 test filenames

# %%
x1_tr, x1_ts = x1_tr.sample(12800), x1_ts.sample(2000)
x2_tr, x2_ts = x2_tr.sample(12800), x2_ts.sample(2000)
x3_tr, x3_ts = x3_tr.sample(12800), x3_ts.sample(2000)
x4_tr, x4_ts = x4_tr.sample(12800), x4_ts.sample(2000)
x5_tr, x5_ts = x5_tr.sample(12800), x5_ts.sample(2000)
x6_tr, x6_ts = x6_tr.sample(12800), x6_ts.sample(2000)

# %% [markdown]
# ## Creating TRAIN/VAL/TEST sets

# %%
X_train = pd.concat([x1_tr, x2_tr, x3_tr, x4_tr, x5_tr, x6_tr], axis=0)
X_test = pd.concat([x1_ts, x2_ts, x3_ts, x4_ts, x5_ts, x6_ts], axis=0)

# %%
y_train = X_train.apply(lambda x: x.split('/')[len(BASE_DIR.split('/'))])
y_test = X_test.apply(lambda x: x.split('/')[len(BASE_DIR.split('/'))])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.fit_transform(y_test)

# %%
X_test = X_test.tolist()

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
X_train,y_train = shuffle(X_train.tolist(),y_train.tolist(), random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=0)

# %%
keys = pd.Series(le.inverse_transform(y_train)).value_counts().index.tolist()
values = pd.Series(y_train).value_counts().index.tolist()
mapping = dict(zip(keys, values))
sorted(mapping.items(), key=lambda x: x[1])
# Out:
# [('Ae. aegypti', 0),
#  ('Ae. albopictus', 1),
#  ('An. arabiensis', 2),
#  ('An. gambiae', 3),
#  ('C. pipiens', 4),
#  ('C. quinquefasciatus', 5)]

# %% [markdown]
# # Modelling

# %%
from utils_train import *
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.utils import to_categorical
from wavhandler import *
import math
from utils_train import TrainConfiguration

# %%
traincf = TrainConfiguration(X=X_train, y=y_train)

# %%
#model_name='mosquitoes_validation_2' 
#setting='raw'
#top_weights_path = TEMP_DATADIR + str(model_name) + '.h5'
targets = 6
#batch_size = 32

# Build the Neural Network
model = Sequential()

model.add(Conv1D(16, 3, activation='relu', input_shape=(5000, 1)))
model.add(Conv1D(16, 3, activation='relu'))
model.add(BatchNormalization())

model.add(Conv1D(32, 3, activation='relu'))
model.add(Conv1D(32, 3, activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling1D(2))
model.add(Conv1D(64, 3, activation='relu'))
model.add(Conv1D(64, 3, activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling1D(2))
model.add(Conv1D(128, 3, activation='relu'))
model.add(Conv1D(128, 3, activation='relu'))
model.add(BatchNormalization())

model.add(MaxPooling1D(2))
model.add(Conv1D(256, 3, activation='relu'))
model.add(Conv1D(256, 3, activation='relu'))
model.add(BatchNormalization())
model.add(GlobalAveragePooling1D())

model.add(Dropout(0.5))
model.add(Dense(targets, activation='softmax'))

model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

callbacks_list = traincf.callbacks_list

# %%
model.fit_generator(train_generator(X_train, y_train, batch_size=traincf.batch_size,
                                   target_names=traincf.target_names,
                                   setting=traincf.setting),
                   steps_per_epoch = int(math.ceil(float(len(X_train)) / float(traincf.batch_size))),
                   epochs=traincf.epochs,
                   validation_data = valid_generator(X_val, y_val,
                                                    batch_size=traincf.batch_size,
                                                    target_names=traincf.target_names,
                                                    setting=traincf.setting),
                    validation_steps=int(math.ceil(float(len(X_test))/float(traincf.batch_size))),
                    callbacks = traincf.callbacks_list)
# Out:
# Epoch 1/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.6672 - accuracy: 0.7524
# Epoch 00001: val_accuracy improved from -inf to 0.30333, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 529s 276ms/step - loss: 0.6671 - accuracy: 0.7524 - val_loss: 3.8958 - val_accuracy: 0.3033
# Epoch 2/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.4353 - accuracy: 0.8397
# Epoch 00002: val_accuracy improved from 0.30333 to 0.55192, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 521s 271ms/step - loss: 0.4353 - accuracy: 0.8397 - val_loss: 4.3470 - val_accuracy: 0.5519
# Epoch 3/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.3755 - accuracy: 0.8613
# Epoch 00003: val_accuracy did not improve from 0.55192
# 1920/1920 [==============================] - 520s 271ms/step - loss: 0.3755 - accuracy: 0.8613 - val_loss: 4.4779 - val_accuracy: 0.5232
# Epoch 4/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.3380 - accuracy: 0.8735
# Epoch 00004: val_accuracy improved from 0.55192 to 0.70200, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 520s 271ms/step - loss: 0.3379 - accuracy: 0.8735 - val_loss: 1.9482 - val_accuracy: 0.7020
# Epoch 5/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.3063 - accuracy: 0.8857
# Epoch 00005: val_accuracy improved from 0.70200 to 0.74800, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 511s 266ms/step - loss: 0.3063 - accuracy: 0.8857 - val_loss: 1.0608 - val_accuracy: 0.7480
# Epoch 6/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2804 - accuracy: 0.8963
# Epoch 00006: val_accuracy did not improve from 0.74800
# 1920/1920 [==============================] - 510s 265ms/step - loss: 0.2804 - accuracy: 0.8963 - val_loss: 1.5988 - val_accuracy: 0.6679
# Epoch 7/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2581 - accuracy: 0.9032
# Epoch 00007: val_accuracy did not improve from 0.74800
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.2581 - accuracy: 0.9032 - val_loss: 2.6649 - val_accuracy: 0.6488
# Epoch 8/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2338 - accuracy: 0.9124
# Epoch 00008: val_accuracy improved from 0.74800 to 0.85125, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.2338 - accuracy: 0.9124 - val_loss: 0.4597 - val_accuracy: 0.8512
# Epoch 9/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.2140 - accuracy: 0.9200
# Epoch 00009: val_accuracy improved from 0.85125 to 0.86658, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.2140 - accuracy: 0.9200 - val_loss: 0.4273 - val_accuracy: 0.8666
# Epoch 10/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1925 - accuracy: 0.9291
# Epoch 00010: val_accuracy did not improve from 0.86658
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.1925 - accuracy: 0.9291 - val_loss: 7.8159 - val_accuracy: 0.4059
# Epoch 11/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1724 - accuracy: 0.9352
# Epoch 00011: val_accuracy did not improve from 0.86658
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.1725 - accuracy: 0.9353 - val_loss: 3.2660 - val_accuracy: 0.6725
# Epoch 12/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1596 - accuracy: 0.9405
# Epoch 00012: val_accuracy did not improve from 0.86658
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.1595 - accuracy: 0.9405 - val_loss: 1.8384 - val_accuracy: 0.7617
# Epoch 13/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.1150 - accuracy: 0.9578
# Epoch 00013: val_accuracy improved from 0.86658 to 0.90450, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.1150 - accuracy: 0.9578 - val_loss: 0.2918 - val_accuracy: 0.9045
# Epoch 14/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0869 - accuracy: 0.9703
# Epoch 00014: val_accuracy did not improve from 0.90450
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.0869 - accuracy: 0.9703 - val_loss: 0.2972 - val_accuracy: 0.9034
# Epoch 15/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0707 - accuracy: 0.9776
# Epoch 00015: val_accuracy did not improve from 0.90450
# 1920/1920 [==============================] - 508s 265ms/step - loss: 0.0707 - accuracy: 0.9776 - val_loss: 0.3132 - val_accuracy: 0.9019
# Epoch 16/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0582 - accuracy: 0.9831
# Epoch 00016: val_accuracy did not improve from 0.90450
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.0582 - accuracy: 0.9831 - val_loss: 0.3240 - val_accuracy: 0.9038
# Epoch 17/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0489 - accuracy: 0.9870
# Epoch 00017: val_accuracy improved from 0.90450 to 0.90658, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.0489 - accuracy: 0.9870 - val_loss: 0.3162 - val_accuracy: 0.9066
# Epoch 18/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0454 - accuracy: 0.9887
# Epoch 00018: val_accuracy did not improve from 0.90658
# 1920/1920 [==============================] - 509s 265ms/step - loss: 0.0453 - accuracy: 0.9887 - val_loss: 0.3286 - val_accuracy: 0.9038
# Epoch 19/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0437 - accuracy: 0.9891
# Epoch 00019: val_accuracy did not improve from 0.90658
# 1920/1920 [==============================] - 510s 266ms/step - loss: 0.0437 - accuracy: 0.9891 - val_loss: 0.3285 - val_accuracy: 0.9038
# Epoch 20/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0419 - accuracy: 0.9903
# Epoch 00020: val_accuracy improved from 0.90658 to 0.90683, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 511s 266ms/step - loss: 0.0419 - accuracy: 0.9903 - val_loss: 0.3229 - val_accuracy: 0.9068
# Epoch 21/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0406 - accuracy: 0.9906
# Epoch 00021: val_accuracy improved from 0.90683 to 0.90783, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0406 - accuracy: 0.9906 - val_loss: 0.3224 - val_accuracy: 0.9078
# Epoch 22/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0391 - accuracy: 0.9912
# Epoch 00022: val_accuracy did not improve from 0.90783
# 1920/1920 [==============================] - 511s 266ms/step - loss: 0.0391 - accuracy: 0.9912 - val_loss: 0.3267 - val_accuracy: 0.9062
# Epoch 23/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0376 - accuracy: 0.9918
# Epoch 00023: val_accuracy did not improve from 0.90783
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0376 - accuracy: 0.9918 - val_loss: 0.3400 - val_accuracy: 0.9037
# Epoch 24/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0366 - accuracy: 0.9926
# Epoch 00024: val_accuracy did not improve from 0.90783
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 1920/1920 [==============================] - 511s 266ms/step - loss: 0.0366 - accuracy: 0.9926 - val_loss: 0.3291 - val_accuracy: 0.9059
# Epoch 25/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0357 - accuracy: 0.9928
# Epoch 00025: val_accuracy did not improve from 0.90783
# 1920/1920 [==============================] - 512s 267ms/step - loss: 0.0357 - accuracy: 0.9928 - val_loss: 0.3324 - val_accuracy: 0.9068
# Epoch 26/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0352 - accuracy: 0.9930
# Epoch 00026: val_accuracy did not improve from 0.90783
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0352 - accuracy: 0.9930 - val_loss: 0.3361 - val_accuracy: 0.9069
# Epoch 27/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9928
# Epoch 00027: val_accuracy improved from 0.90783 to 0.90808, saving model to /home/kalfasyan/projects/wingbeat_frequencies/Jupyter_Notebooks/temp_data/test.h5
# 1920/1920 [==============================] - 512s 267ms/step - loss: 0.0351 - accuracy: 0.9928 - val_loss: 0.3250 - val_accuracy: 0.9081
# Epoch 28/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0346 - accuracy: 0.9931
# Epoch 00028: val_accuracy did not improve from 0.90808
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0346 - accuracy: 0.9931 - val_loss: 0.3381 - val_accuracy: 0.9056
# Epoch 29/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0350 - accuracy: 0.9927
# Epoch 00029: val_accuracy did not improve from 0.90808
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0350 - accuracy: 0.9927 - val_loss: 0.3312 - val_accuracy: 0.9060
# Epoch 30/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0349 - accuracy: 0.9933
# Epoch 00030: val_accuracy did not improve from 0.90808
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0349 - accuracy: 0.9932 - val_loss: 0.3304 - val_accuracy: 0.9075
# Epoch 31/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0343 - accuracy: 0.9933
# Epoch 00031: val_accuracy did not improve from 0.90808
# 1920/1920 [==============================] - 512s 266ms/step - loss: 0.0343 - accuracy: 0.9933 - val_loss: 0.3393 - val_accuracy: 0.9067
# Epoch 32/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9929
# Epoch 00032: val_accuracy did not improve from 0.90808
# 1920/1920 [==============================] - 511s 266ms/step - loss: 0.0344 - accuracy: 0.9929 - val_loss: 0.3244 - val_accuracy: 0.9081
# Epoch 33/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9933
# Epoch 00033: val_accuracy did not improve from 0.90808
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 1920/1920 [==============================] - 512s 267ms/step - loss: 0.0351 - accuracy: 0.9933 - val_loss: 0.3413 - val_accuracy: 0.9047
# Epoch 34/100
# 1919/1920 [============================>.] - ETA: 0s - loss: 0.0342 - accuracy: 0.9936
# Epoch 00034: val_accuracy did not improve from 0.90808
# 1920/1920 [==============================] - 511s 266ms/step - loss: 0.0342 - accuracy: 0.9936 - val_loss: 0.3318 - val_accuracy: 0.9065
# Epoch 00034: early stopping

# %%
model.load_weights(traincf.top_weights_path)
y_pred = model.predict_generator(valid_generator(X_test, 
                                                    y_test, 
                                                    batch_size=traincf.batch_size, 
                                                    setting=traincf.setting, 
                                                    target_names=traincf.target_names),
        steps = int(math.ceil(float(len(X_test)) / float(traincf.batch_size))))

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
x = confusion_matrix(np.array(y_test), np.argmax(y_pred, axis=1))

plt.figure(figsize=(16,12))
sns.set(font_scale=1.2)
ticks = ['Ae. aegypti',' Ae. albopictus','An. arabiensis','An. gambiae','C. pipiens','C. quinquefasciatus']
ticks_short = ['Ae. aeg','Ae. alb','An. arab','An. gambiae','C. pip','C. quin']
sns.heatmap(x, annot=True, fmt='.0f', xticklabels=ticks, yticklabels=ticks_short)

# %%
model.load_weights(traincf.top_weights_path)
loss, acc = model.evaluate_generator(valid_generator(X_test, 
                                                    y_test, 
                                                    batch_size=traincf.batch_size, 
                                                    setting=traincf.setting, 
                                                    target_names=traincf.target_names),
        steps = int(math.ceil(float(len(X_test)) / float(traincf.batch_size))))

print('loss', loss)
print('Test accuracy:', acc)
# Out:
# loss 1.7565923194543769
# Test accuracy: 0.6849167

# %%
from sklearn.metrics import balanced_accuracy_score

balanced_accuracy_score(np.array(y_test), np.argmax(y_pred, axis=1))
# Out:
# 0.6849166666666666

# %%
# Out:
# (12000,)
