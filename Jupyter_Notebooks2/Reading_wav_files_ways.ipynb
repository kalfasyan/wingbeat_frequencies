# %%
# %reset -f

import matplotlib.pyplot as plt

# %%
from scipy.io.wavfile import read

# %%
path = '/home/kalfasyan/data/wingbeats/LG/LG_zapr_26_09/D_18_09_19_04_38_46/F180919_043847_133_G_120_T_26.6_H_68.7.wav'

# %%
# %%timeit
read(path)
# Out:
# /home/kalfasyan/anaconda3/envs/wbtf/lib/python3.7/site-packages/ipykernel_launcher.py:1: WavFileWarning: Reached EOF prematurely; finished at 10044 bytes, expected 16044 bytes from header.
#   """Entry point for launching an IPython kernel.
# 17.3 µs ± 92.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
import soundfile as sf

# %%
# %%timeit
wavdata, _ = sf.read(path)
# Out:
# 63.6 µs ± 918 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import librosa

# %%
# %%timeit
librosa.load(path)[0]
# Out:
# 9.87 ms ± 43.9 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.plot(read(path)[1]);
# Out:
# /home/kalfasyan/anaconda3/envs/wbtf/lib/python3.7/site-packages/ipykernel_launcher.py:1: WavFileWarning: Reached EOF prematurely; finished at 10044 bytes, expected 16044 bytes from header.
#   """Entry point for launching an IPython kernel.

# %%
wavdata, _ = sf.read(path)
plt.plot(wavdata);

# %%
plt.plot(librosa.load(path)[0]);

# %%
wavdata, z = sf.read(path)

# %%
z
# Out:
# 8000
